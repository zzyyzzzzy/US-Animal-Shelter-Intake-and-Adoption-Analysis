# %%
import pandas, sys
import pandas as pd


a = pd.read_csv("cat_adopted_2020.csv")
b = pd.read_csv("dog_adopted_2020.csv")

# %%
c=pd.concat([a,b])

# %%
c.shape
# Out:
# (36197, 26)

# %%
c.head()
# Out:
#          id organization_id type    age  gender    size   coat  \
# 0  50167537           MD307  Cat   Baby  Female  Medium  Short
# 1  50167559           NV129  Cat   Baby  Female  Medium  Short
# 2  50167410            CT40  Cat   Baby  Female  Medium  Short
# 3  50167494          NY1063  Cat  Young  Female  Medium  Short
# 4  50147331           WI394  Cat  Adult    Male   Large  Short
#
#   organization_animal_id   status              published_at  ...  \
# 0                missing  adopted  2020-12-30T23:59:45+0000  ...
# 1                  dec20  adopted  2020-12-30T23:58:53+0000  ...
# 2                missing  adopted  2020-12-30T23:56:30+0000  ...
# 3                missing  adopted  2020-12-30T23:55:50+0000  ...
# 4                missing  adopted  2020-12-30T23:52:52+0000  ...
#
#          colors_primary colors_secondary attributes_spayed_neutered  \
# 0  Dilute Tortoiseshell          missing                       True
# ...

# %%
c.to_csv('catdog_adopted_2020.csv')
