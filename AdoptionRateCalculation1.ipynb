# %%
import pandas, sys
import pandas as pd


df = pd.read_csv("catdog_adopted_2020.csv")
# Out:
# /Users/cc/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0        id organization_id type    age  gender    size   coat  \
# 0           0  50167537           MD307  Cat   Baby  Female  Medium  Short
# 1           1  50167559           NV129  Cat   Baby  Female  Medium  Short
# 2           2  50167410            CT40  Cat   Baby  Female  Medium  Short
# 3           3  50167494          NY1063  Cat  Young  Female  Medium  Short
# 4           4  50147331           WI394  Cat  Adult    Male   Large  Short
#
#   organization_animal_id   status  ...        colors_primary colors_secondary  \
# 0                missing  adopted  ...  Dilute Tortoiseshell          missing
# 1                  dec20  adopted  ...     Buff / Tan / Fawn          missing
# 2                missing  adopted  ...                 Black          missing
# 3                missing  adopted  ...          Gray & White          missing
# 4                missing  adopted  ...                 White          missing
#
# ...

# %%
df1=df.groupby('state').count()

# %%
df1
# Out:
#        Unnamed: 0    id  organization_id  type   age  gender  size  coat  \
# state
# AB             32    32               32    32    32      32    32    32
# AK             57    57               57    57    57      57    57    57
# AL            587   587              587   587   587     587   587   587
# AR            269   269              269   269   269     269   269   269
# AZ            726   726              726   726   726     726   726   726
# ...           ...   ...              ...   ...   ...     ...   ...   ...
# VT             76    76               76    76    76      76    76    76
# WA            832   832              832   832   832     832   832   832
# WI           1178  1178             1178  1178  1178    1178  1178  1178
# WV            271   271              271   271   271     271   271   271
# WY             98    98               98    98    98      98    98    98
#
#        organization_animal_id  status  ...  colors_primary  colors_secondary  \
# ...

# %%
df2=df1['id']

# %%
df2
# Out:
# state
# AB      32
# AK      57
# AL     587
# AR     269
# AZ     726
#       ...
# VT      76
# WA     832
# WI    1178
# WV     271
# WY      98
# Name: id, Length: 61, dtype: int64

# %%
df2.to_csv('adopted_count_state.csv')

# %%
df1=pd.read_csv('adopted_count_state.csv')
df2=pd.read_csv('population_by_state.csv')

# %%
df3=pd.read_csv('StateFullName.csv')

# %%
df4=pd.merge(df3, df2, on='description')

# %%
df5=pd.merge(df4,df1,on='code')

# %%
df5
# Out:
#    code     description  Population        lat        long  count
# 0    AK          Alaska      731545  58.301598 -134.420212     57
# 1    AL         Alabama     4903185  32.377716  -86.300568    587
# 2    AR        Arkansas     3017804  34.746613  -92.288986    269
# 3    AZ         Arizona     7278717  33.448143 -112.096962    726
# 4    CA      California    39512223  38.576668 -121.493629   2746
# 5    CO        Colorado     5758736  39.739227 -104.984856    614
# 6    CT     Connecticut     3565287  41.764046  -72.682198    681
# 7    DE        Delaware      973764  39.157307  -75.519722     68
# 8    FL         Florida    21477737  30.438118  -84.281296   1743
# 9    GA         Georgia    10617423  33.749027  -84.388229   1070
# 10   HI          Hawaii     1415872  21.307442 -157.857376     24
# 11   IA            Iowa     3155070  41.591087  -93.603729    403
# 12   ID           Idaho     1787065  43.617775 -116.199722    192
# ...

# %%
df5['adoption_rate']=df5['count']/df5['Population']

# %%
df5
# Out:
#    code     description  Population        lat        long  count  \
# 0    AK          Alaska      731545  58.301598 -134.420212     57
# 1    AL         Alabama     4903185  32.377716  -86.300568    587
# 2    AR        Arkansas     3017804  34.746613  -92.288986    269
# 3    AZ         Arizona     7278717  33.448143 -112.096962    726
# 4    CA      California    39512223  38.576668 -121.493629   2746
# 5    CO        Colorado     5758736  39.739227 -104.984856    614
# 6    CT     Connecticut     3565287  41.764046  -72.682198    681
# 7    DE        Delaware      973764  39.157307  -75.519722     68
# 8    FL         Florida    21477737  30.438118  -84.281296   1743
# 9    GA         Georgia    10617423  33.749027  -84.388229   1070
# 10   HI          Hawaii     1415872  21.307442 -157.857376     24
# 11   IA            Iowa     3155070  41.591087  -93.603729    403
# 12   ID           Idaho     1787065  43.617775 -116.199722    192
# ...

# %%
df5.to_csv('adoption_rate.csv')
